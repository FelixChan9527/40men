# %%
cd /content/drive/MyDrive/Colab Notebooks/my_own
# Out:
# /content/drive/MyDrive/Colab Notebooks/my_own

# %%
# !python train.py
# Out:
# /content/drive/My Drive/Colab Notebooks/my_own/model.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.softmax(self.dense3(x))
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 45, 55]             320
#             Conv2d-2          [-1, 192, 10, 13]          55,488
#             Linear-3                  [-1, 120]         691,320
#            Dropout-4                  [-1, 120]               0
#             Linear-5                   [-1, 72]           8,712
#             Linear-6                   [-1, 40]           2,920
# ...
# Total params: 758,760
# Trainable params: 758,760
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 0.80
# Params size (MB): 2.89
# ...

# %%
# !/opt/bin/nvidia-smi

# %%
# !tensorboard --logdir=logs --port=5658
